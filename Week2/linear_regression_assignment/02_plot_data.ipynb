# %%
import numpy as np
import seaborn as sns

# %%
def plot_data(x, y):
    ax = sns.scatterplot(x=X, y=y, marker='x', s=100)
    ax.set(title='Plot', xlabel='Population', ylabel='Revenue')

# %%
data = np.genfromtxt('ex1data1.txt', delimiter=',')
X, y = data[:,0], data[:,1]

# %%
plot_data(X, y)
